# %%
from DataGeneration import *
import polars as pl
from torchsummary import summary
import torch 
import torch.nn as nn
import psutil


from torch.utils.data import TensorDataset,DataLoader,random_split
import time
import multiprocessing as mp

# %%
def print_memory_usage():
    process = psutil.Process()
    print(f"Memory usage: {process.memory_info().rss / 1e9:.2f} GB")

# %%
a = datagen()
a.apply_simulation()
df = a.retrieve_df()

# %%
a.df_to_tensor()
a.standard_normalization()

# %%
# class RNN(nn.Module):
    
#     def __init__(self,input_len,hidden_size_1,hidden_size_2,out_len):
        
#         super(RNN, self).__init__()
        
#         self.hidden_size_1 = hidden_size_1
        
#         self.hidden_size_2 = hidden_size_2
        
#         self.input_size = input_len
        
#         self.GRU_1 = nn.GRU(input_len,hidden_size_1,batch_first=True)
        
#         self.GRU_2 = nn.GRU(hidden_size_1,hidden_size_2, batch_first=True)
        
#         self.out_layer = nn.Linear(hidden_size_2,out_len)

#     def forward(self,X):
#         h1 = torch.zeros(1,X.size(0),self.hidden_size_1).to(device)
#         h2 = torch.zeros(1,X.size(0),self.hidden_size_2).to(device)
        

#         out_1 , _ = self.GRU_1(X,h1)
#         out_2 , _ = self.GRU_2(out_1,h2)
#         pred = self.out_layer(out_2)
        
#         return pred

# %%
# class RNN(nn.Module):
#     def __init__(self, input_len, hidden_size_1, hidden_size_2, out_len):
#             super(RNN, self).__init__()
            
#             self.hidden_size_1 = hidden_size_1
#             self.hidden_size_2 = hidden_size_2
#             self.input_size = input_len
            
#             # Define LSTM layers
#             self.LSTM_1 = nn.LSTM(input_len, hidden_size_1, batch_first=True)
#             self.LSTM_2 = nn.LSTM(hidden_size_1, hidden_size_2, batch_first=True)
            
#             # Define output layer
#             self.out_layer = nn.Linear(hidden_size_2, out_len)
            
#     def forward(self, X):
#             # hidden_state_1 = torch.zeros(1, X.size(0), self.hidden_size_1).to(device)
#             # cell_state_1 = torch.zeros(1, X.size(0), self.hidden_size_1).to(device)
#             # hidden_state_2 = torch.zeros(1, X.size(0), self.hidden_size_2).to(device)
#             # cell_state_2 = torch.zeros(1, X.size(0), self.hidden_size_2).to(device)
            
#             out_1, _ = self.LSTM_1(X) #(hidden_state_1, cell_state_1)
            
#             out_2, _ = self.LSTM_2(out_1)
            
#             pred = self.out_layer(out_2)
            
#             return pred

# %%
# class RNN(nn.Module):
#     def __init__(self, input_len, hidden_size_1, hidden_size_2, out_len):
#         super(RNN, self).__init__()
        
#         self.model = nn.Sequential(
#             nn.LSTM(input_len, hidden_size_1, batch_first=True),
#             nn.LSTM(hidden_size_1, hidden_size_2, batch_first=True),
#             nn.Linear(hidden_size_2, out_len)
#         )
    
#     def forward(self, x):
        
#         h1 = torch.zeros(1, x.size(0), self.model[0].hidden_size).to(x.device)
#         c1 = torch.zeros(1, x.size(0), self.model[0].hidden_size).to(x.device)
#         h2 = torch.zeros(1, x.size(0), self.model[1].hidden_size).to(x.device)
#         c2 = torch.zeros(1, x.size(0), self.model[1].hidden_size).to(x.device)
        

#         x, (h1, c1) = self.model[0](x, (h1, c1))
        

#         x, (h2, c2) = self.model[1](x, (h2, c2))
        
  
#         x = self.model[2](x)  
        
#         return x

# %%
class RNN(nn.Module):
    def __init__(self, input_len, hidden_size_1, hidden_size_2, out_len):
        super(RNN, self).__init__()
        
        self.model = nn.Sequential(
            nn.GRU(input_len, hidden_size_1, batch_first=True),
            nn.GRU(hidden_size_1, hidden_size_2, batch_first=True),
            nn.Linear(hidden_size_2, out_len)
        )
    
    def forward(self, x):
        
        h1 = torch.zeros(1, x.size(0), self.model[0].hidden_size).to(x.device)
      
        h2 = torch.zeros(1, x.size(0), self.model[1].hidden_size).to(x.device)
       
        

        x, _ = self.model[0](x, h1)
        

        x, _= self.model[1](x, h2)
        
  
        x = self.model[2](x)  
        
        return x

# %%
torch.set_num_threads(mp.cpu_count())
device = torch.device('mps')

Model = RNN(4,64,32,2)
Model = Model.to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(Model.parameters(),lr=0.001,eps=1e-7)

# %%
display(Model)
# Out:
# RNN(
#   (model): Sequential(
#     (0): GRU(4, 64, batch_first=True)
#     (1): GRU(64, 32, batch_first=True)
#     (2): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %%
def train(model, dataset, epochs=100, batch_size=256,val_split=0.1):
    
    val_split = val_split
    val_size = int(val_split * len(dataset))
    train_size = len(dataset) - val_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    batch_size = 256
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=mp.cpu_count(),
                              pin_memory=True,persistent_workers = True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True,num_workers=mp.cpu_count(),
                            pin_memory=True,persistent_workers = True)
    
    tic = time.perf_counter()
    train_list=[]
    val_list= []
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)
            optimizer.zero_grad()
            output = model(batch_X)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            
        train_loss /= len(train_loader)
        

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val = X_val.to(device)
                y_val = y_val.to(device)
                output = model(X_val)
                loss = criterion(output, y_val)
                val_loss += loss.item()
                
        val_loss /= len(val_loader)
        # if epoch+1 % 10 == 0:
        toc = time.perf_counter()
        print(f'Epoch: {epoch}, Elapsed: {(toc - tic):.0f} sec')
        tic = time.perf_counter()
        print("Loss for Training on Epoch " + str(epoch) + " is " + str(val_loss))
        val_list.append(val_loss)
        train_list.append(train_loss)
    return train_list,val_list
            #print_memory_usage()

# %%
X_train_np= a.X_train_norm.astype(np.float32)
y_train_np= a.y_train_norm.astype(np.float32)
X_train_tensor = torch.from_numpy(X_train_np)
y_train_tensor = torch.from_numpy(y_train_np)
# X_train_tensor = torch.FloatTensor(a.X_train.astype(np.float32))
# y_train_tensor = torch.FloatTensor(a.y_train.astype(np.float32))

# %%
dataset = TensorDataset(X_train_tensor, y_train_tensor)

# %%
trainloss,valloss=train(Model, dataset, epochs=100, batch_size=256,val_split=0.1)
# Out:
# Epoch: 0, Elapsed: 19 sec
# Loss for Training on Epoch 0 is 0.022491359669301245
# Epoch: 1, Elapsed: 9 sec
# Loss for Training on Epoch 1 is 0.019939158560225257
# Epoch: 2, Elapsed: 9 sec
# Loss for Training on Epoch 2 is 0.011358650694428771
# Loss for Training on Epoch 95 is 3.582226963771973e-05
# Epoch: 96, Elapsed: 9 sec
# Loss for Training on Epoch 96 is 2.610540852603865e-05
# Epoch: 97, Elapsed: 9 sec
# Loss for Training on Epoch 97 is 3.115193323066234e-05
# Epoch: 98, Elapsed: 9 sec
# Loss for Training on Epoch 98 is 1.7450644851056427e-05
# Epoch: 99, Elapsed: 9 sec
# Loss for Training on Epoch 99 is 1.7419595628275096e-05

# %%
with torch.no_grad():
    Model.eval()
    y_pred = Model(torch.from_numpy(a.X_test_norm.astype(np.float32)).to(device))
    test_loss = criterion(y_pred, torch.from_numpy(a.y_test_norm.astype(np.float32)).to(device))
    print('test loss is {}'.format(test_loss))
# Out:
# test loss is 1.747852365951985e-05

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(trainloss) + 1)
plt.plot(epochs, trainloss, 'r', label='Training loss')
plt.plot(epochs, valloss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
import joblib
x_scaler = joblib.load('standardscaler/xscaler.pkl')
y_scaler = joblib.load('standardscaler/yscaler.pkl')




y = np.linspace(-100, 100, 100000, endpoint=True)

x_upper = list()
x_lower = list()
y_plot = list()

for i in y:
    sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
    if sqrt >= 0:
        y_plot.append(i)
        x_upper.append((-4400 * i + sqrt) / 212000)
        x_lower.append((-4400 * i - sqrt) / 212000)
        pass
    pass


def manual_minmax_inverse(X_scaled, X_min, X_max):
    return X_scaled * (X_max - X_min) + X_min
    
plt.figure(figsize=(10,10))

X_test = torch.from_numpy(a.X_test_norm.astype(np.float32))
y_test = a.y_test
X_test = X_test.to(device)

# plot the first 10 samples and their trajectories
Model.eval()
y_predict = Model(X_test).cpu()
y_predict = y_scaler.inverse_transform(y_predict.detach().numpy().reshape(-1,2)).reshape(-1,10,2)
#y_test =  y_scaler.inverse_transform(y_test.numpy().reshape(-1,2)).reshape(-1,10,2)
X_plot =  a.X_test


for i in range(500):
    if i == 0:  # only add label to 1 data point
        plt.plot(X_plot[i, 0, 0], X_plot[i, 0, 1], marker="*", markersize=15,color='orange')
        plt.plot(y_test[i, :, 0], y_test[i, :, 1], color='cyan', lw=2, label='Test')
        plt.plot(y_predict[i, :, 0], y_predict[i, :, 1], color='black', lw=2, ls=':', label='Predicted')
    else:
        plt.plot(X_plot[i, 0, 0], X_plot[i, 0, 1], marker="*", markersize=15,color='orange')
        plt.plot(y_test[i, :, 0], y_test[i, :, 1], color='cyan', lw=2)
        plt.plot(y_predict[i, :, 0], y_predict[i, :, 1], color='black', lw=2, ls=':')

    
# plot stability region        
plt.plot(x_lower, y_plot, color='steelblue')
plt.plot(x_upper, y_plot, color='steelblue')
plt.ylim([-100, 100])
plt.xlim([-2, 2])

plt.xlabel("C_A - C_As")
plt.ylabel("T - T_s")
plt.legend()
plt.show()
# Out:
# /var/folders/21/j8pd743n579fmcql4fstpcx80000gn/T/ipykernel_27279/1914631951.py:15: RuntimeWarning: invalid value encountered in sqrt
#   sqrt = np.sqrt(-2688000 * i**2 + 15772800000)
